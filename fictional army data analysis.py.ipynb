# %%
import pandas as pd

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
df = pd.DataFrame(raw_data)
df = df.set_index('origin')

# %%
df.head(5)
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
# regiment     12 non-null object
# company      12 non-null object
# deaths       12 non-null int64
# battles      12 non-null int64
# size         12 non-null int64
# veterans     12 non-null int64
# readiness    12 non-null int64
# armored      12 non-null int64
# deserters    12 non-null int64
# origin       12 non-null object
# dtypes: int64(7), object(3)
# memory usage: 1.0+ KB

# %%
df.shape[1]
# Out:
# 10

# %%
df.shape[0]
# Out:
# 12

# %%
#print only column veterens
df['veterans'].head(5)
# Out:
# origin
# Arizona        1
# California     5
# Texas         62
# Florida       26
# Maine         73
# Name: veterans, dtype: int64

# %%
#print the name of all the columns
df.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %%
#select the deaths,size,deserters, columns from maine and alska
df.loc[df.origin.isin(['Maine','Alaska']), ['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
df.iloc[3:7, 3:6]
# Out:
#          battles  size  veterans
# origin
# Florida        2  1400        26
# Maine          4  1592        73
# Iowa           7  1006        37
# Alaska         8   987       949

# %%
#select evrey row after the fourth row
df.iloc[3:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# ...

# %%
#select evry row upto the fourth row
df.iloc[:3]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31

# %%
#select the 3rd column upto the 7th column
df.iloc[:,4:7]
# Out:
#             size  veterans  readiness
# origin
# Arizona     1045         1          1
# California   957         5          2
# Texas       1099        62          3
# Florida     1400        26          3
# Maine       1592        73          2
# Iowa        1006        37          1
# Alaska       987       949          2
# Washington   849        48          3
# Oregon       973        48          2
# Wyoming     1005       435          1
# Louisana    1099        63          2
# Georgia     1523       345          3

# %%
#select the rows where deaths greater than 50
df[df.deaths > 50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters      origin
# origin
# Arizona           1          4     Arizona
# California        0         24  California
# Florida           1          2     Florida
# Iowa              1          4        Iowa
# Alaska            0         24      Alaska
# ...

# %%
#select the rows where deaths greater than 500 and less then 
df[(df['deaths'] > 500) |(df['deaths'] < 50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %%
[df.regiment != 'Dragoons']
# Out:
# [origin
#  Arizona        True
#  California     True
#  Texas          True
#  Florida        True
#  Maine         False
#  Iowa          False
#  Alaska        False
#  Washington    False
#  Oregon         True
#  Wyoming        True
#  Louisana       True
#  Georgia        True
#  Name: regiment, dtype: bool]

# %%
df.loc[['Arizon','Texas']]
# Out:
# E:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#           regiment company  deaths  battles    size  veterans  readiness  \
# origin
# Arizon         NaN     NaN     NaN      NaN     NaN       NaN        NaN
# Texas   Nighthawks     2nd    25.0      2.0  1099.0      62.0        3.0
#
#         armored  deserters
# origin
# Arizon      NaN        NaN
# Texas       1.0       31.0

# %%
#select the third cell in the row named arizon
#df.loc[['Arizon'], ['deaths']]
df.iloc[[0], df.columns.get_loc('deaths')]
# Out:
# origin
# Arizona    523
# Name: deaths, dtype: int64

# %%
#select the third cell down in the columns named deaths
df.iloc[[2],df.columns.get_loc('deaths')]
# Out:
# origin
# Texas    25
# Name: deaths, dtype: int64
